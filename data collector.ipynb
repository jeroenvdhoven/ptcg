# %%
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import requests
import os
import multiprocessing

# %%
base_url = 'https://bulbapedia.bulbagarden.net'
url = base_url + '/wiki/Pok%C3%A9mon_Trading_Card_Game'

# %% [markdown]
# # Extract series and links

# %%
def find_links(series):
    """
    Return all links associated with a list of series
    
    """
    all_links = []
    for serie in series:
        all_links.extend(serie.find_all('li'))
    
    return all_links

# %%
def extract_serie_link(links):
    """
    Find the main link for all card sets
    
    """
    sets = [l.find_all('a')[-1] for l in links]
    return {s.text: base_url + s['href'] for s in sets}

# %%
req_data = requests.get(url)
soup = BeautifulSoup(req_data.content)
series = soup.find_all('table')[1:3]

all_links = find_links(series)
sets = extract_serie_link(all_links)

# %%
sets
# Out:
# {'Base Set': 'https://bulbapedia.bulbagarden.net/wiki/Base_Set_(TCG)',
#  'Jungle': 'https://bulbapedia.bulbagarden.net/wiki/Jungle_(TCG)',
#  'Fossil': 'https://bulbapedia.bulbagarden.net/wiki/Fossil_(TCG)',
#  'Base Set 2': 'https://bulbapedia.bulbagarden.net/wiki/Base_Set_2_(TCG)',
#  'Team Rocket': 'https://bulbapedia.bulbagarden.net/wiki/Team_Rocket_(TCG)',
#  'Gym Heroes': 'https://bulbapedia.bulbagarden.net/wiki/Gym_Heroes_(TCG)',
#  'Gym Challenge': 'https://bulbapedia.bulbagarden.net/wiki/Gym_Challenge_(TCG)',
#  'Neo Genesis': 'https://bulbapedia.bulbagarden.net/wiki/Neo_Genesis_(TCG)',
#  'Neo Discovery': 'https://bulbapedia.bulbagarden.net/wiki/Neo_Discovery_(TCG)',
#  'Neo Revelation': 'https://bulbapedia.bulbagarden.net/wiki/Neo_Revelation_(TCG)',
#  'Neo Destiny': 'https://bulbapedia.bulbagarden.net/wiki/Neo_Destiny_(TCG)',
#  'Legendary Collection': 'https://bulbapedia.bulbagarden.net/wiki/Legendary_Collection_(TCG)',
#  'Expedition Base Set': 'https://bulbapedia.bulbagarden.net/wiki/Expedition_Base_Set_(TCG)',
#  'Aquapolis': 'https://bulbapedia.bulbagarden.net/wiki/Aquapolis_(TCG)',
#  'Skyridge': 'https://bulbapedia.bulbagarden.net/wiki/Skyridge_(TCG)',
#  'Southern Islands': 'https://bulbapedia.bulbagarden.net/wiki/Southern_Islands_(TCG)',
#  'Sample Set': 'https://bulbapedia.bulbagarden.net/wiki/Sample_Set_(TCG)',
#  'Best of Game Cards': 'https://bulbapedia.bulbagarden.net/wiki/Best_of_Game_Cards_(TCG)',
#  'Wizards Black Star Promos': 'https://bulbapedia.bulbagarden.net/wiki/Wizards_Black_Star_Promos_(TCG)',
#  'W Promotional cards': 'https://bulbapedia.bulbagarden.net/wiki/W_Promotional_cards_(TCG)',
#  'Miscellaneous Promotional cards (TCG)/1999-2008': 'https://bulbapedia.bulbagarden.net/wiki/Miscellaneous_Promotional_cards_(TCG)/1999-2008',
#  'Crosstrainer': 'https://bulbapedia.bulbagarden.net/wiki/Crosstrainer_(TCG)',
#  'Unnamed Wizards Set': 'https://bulbapedia.bulbagarden.net/wiki/Unnamed_Wizards_Set_(TCG)',
#  'Jamboree': 'https://bulbapedia.bulbagarden.net/wiki/Jamboree_(TCG)',
#  'Legendary Collection 2': 'https://bulbapedia.bulbagarden.net/wiki/Legendary_Collection_2_(TCG)',
#  'Crimson Invasion': 'https://bulbapedia.bulbagarden.net/wiki/Crimson_Invasion_(TCG)',
#  'Ultra Prism': 'https://bulbapedia.bulbagarden.net/wiki/Ultra_Prism_(TCG)',
#  'Forbidden Light': 'https://bulbapedia.bulbagarden.net/wiki/Forbidden_Light_(TCG)',
#  'Celestial Storm': 'https://bulbapedia.bulbagarden.net/wiki/Celestial_Storm_(TCG)',
#  'Dragon Majesty': 'https://bulbapedia.bulbagarden.net/wiki/Dragon_Majesty_(TCG)',
#  'Lost Thunder': 'https://bulbapedia.bulbagarden.net/wiki/Lost_Thunder_(TCG)',
#  'Team Up': 'https://bulbapedia.bulbagarden.net/wiki/Team_Up_(TCG)',
#  'Detective Pikachu': 'https://bulbapedia.bulbagarden.net/wiki/Detective_Pikachu_(TCG)',
#  'Unbroken Bonds': 'https://bulbapedia.bulbagarden.net/wiki/Unbroken_Bonds_(TCG)',
#  'Unified Minds': 'https://bulbapedia.bulbagarden.net/wiki/Unified_Minds_(TCG)',
#  'Hidden Fates': 'https://bulbapedia.bulbagarden.net/wiki/Hidden_Fates_(TCG)',
#  'Cosmic Eclipse': 'https://bulbapedia.bulbagarden.net/wiki/Cosmic_Eclipse_(TCG)',
#  '2004 World Championships': 'https://bulbapedia.bulbagarden.net/wiki/World_Championships_Deck_(TCG)#2004_World_Championships',
#  '2005 World Championships': 'https://bulbapedia.bulbagarden.net/wiki/World_Championships_Deck_(TCG)#2005_World_Championships',
#  '2006 World Championships': 'https://bulbapedia.bulbagarden.net/wiki/World_Championships_Deck_(TCG)#2006_World_Championships',
#  '2007 World Championships': 'https://bulbapedia.bulbagarden.net/wiki/World_Championships_Deck_(TCG)#2007_World_Championships',
#  '2008 World Championships': 'https://bulbapedia.bulbagarden.net/wiki/World_Championships_Deck_(TCG)#2008_World_Championships',
#  '2009 World Championships': 'https://bulbapedia.bulbagarden.net/wiki/World_Championships_Deck_(TCG)#2009_World_Championships',
#  '2010 World Championships': 'https://bulbapedia.bulbagarden.net/wiki/World_Championships_Deck_(TCG)#2010_World_Championships',
#  '2011 World Championships': 'https://bulbapedia.bulbagarden.net/wiki/World_Championships_Deck_(TCG)#2011_World_Championships',
#  '2012 World Championships': 'https://bulbapedia.bulbagarden.net/wiki/World_Championships_Deck_(TCG)#2012_World_Championships',
#  '2013 World Championships': 'https://bulbapedia.bulbagarden.net/wiki/World_Championships_Deck_(TCG)#2013_World_Championships',
#  '2014 World Championships': 'https://bulbapedia.bulbagarden.net/wiki/World_Championships_Deck_(TCG)#2014_World_Championships',
#  '2015 World Championships': 'https://bulbapedia.bulbagarden.net/wiki/World_Championships_Deck_(TCG)#2015_World_Championships',
#  '2016 World Championships': 'https://bulbapedia.bulbagarden.net/wiki/World_Championships_Deck_(TCG)#2016_World_Championships',
#  '2017 World Championships': 'https://bulbapedia.bulbagarden.net/wiki/World_Championships_Deck_(TCG)#2017_World_Championships',
#  '2018 World Championships': 'https://bulbapedia.bulbagarden.net/wiki/World_Championships_Deck_(TCG)#2018_World_Championships',
#  'EX Trainer Kit': 'https://bulbapedia.bulbagarden.net/wiki/EX_Trainer_Kit_(TCG)',
#  'EX Trainer Kit 2': 'https://bulbapedia.bulbagarden.net/wiki/EX_Trainer_Kit_2_(TCG)',
#  'Diamond & Pearl Trainer Kit': 'https://bulbapedia.bulbagarden.net/wiki/Diamond_%26_Pearl_Trainer_Kit_(TCG)',
#  'HS Trainer Kit': 'https://bulbapedia.bulbagarden.net/wiki/HS_Trainer_Kit_(TCG)',
#  'Black & White Trainer Kit': 'https://bulbapedia.bulbagarden.net/wiki/Black_%26_White_Trainer_Kit_(TCG)',
#  'XY Trainer Kit': 'https://bulbapedia.bulbagarden.net/wiki/XY_Trainer_Kit_(TCG)',
#  'XY Trainer Kit: Bisharp & Wigglytuff': 'https://bulbapedia.bulbagarden.net/wiki/XY_Trainer_Kit:_Bisharp_%26_Wigglytuff_(TCG)',
#  'XY Trainer Kit: Latias & Latios': 'https://bulbapedia.bulbagarden.net/wiki/XY_Trainer_Kit:_Latias_%26_Latios_(TCG)',
#  'XY Trainer Kit: Pikachu Libre & Suicune': 'https://bulbapedia.bulbagarden.net/wiki/XY_Trainer_Kit:_Pikachu_Libre_%26_Suicune_(TCG)',
#  'Sun & Moon Trainer Kit: Lycanroc & Alolan Raichu': 'https://bulbapedia.bulbagarden.net/wiki/Sun_%26_Moon_Trainer_Kit:_Lycanroc_%26_Alolan_Raichu_(TCG)',
#  'Sun & Moon Trainer Kit: Alolan Sandslash & Alolan Ninetales': 'https://bulbapedia.bulbagarden.net/wiki/Sun_%26_Moon_Trainer_Kit:_Alolan_Sandslash_%26_Alolan_Ninetales_(TCG)',
#  'Nintendo Black Star Promos': 'https://bulbapedia.bulbagarden.net/wiki/Nintendo_Black_Star_Promos_(TCG)',
#  'DP Black Star Promos': 'https://bulbapedia.bulbagarden.net/wiki/DP_Black_Star_Promos_(TCG)',
#  'HGSS Black Star Promos': 'https://bulbapedia.bulbagarden.net/wiki/HGSS_Black_Star_Promos_(TCG)',
#  'BW Black Star Promos': 'https://bulbapedia.bulbagarden.net/wiki/BW_Black_Star_Promos_(TCG)',
#  'XY Black Star Promos': 'https://bulbapedia.bulbagarden.net/wiki/XY_Black_Star_Promos_(TCG)',
#  'SM Black Star Promos': 'https://bulbapedia.bulbagarden.net/wiki/SM_Black_Star_Promos_(TCG)',
#  'SWSH Black Star Promos': 'https://bulbapedia.bulbagarden.net/wiki/SWSH_Black_Star_Promos_(TCG)',
#  'POP Series 1': 'https://bulbapedia.bulbagarden.net/wiki/POP_Series_1_(TCG)',
#  'POP Series 2': 'https://bulbapedia.bulbagarden.net/wiki/POP_Series_2_(TCG)',
#  'POP Series 3': 'https://bulbapedia.bulbagarden.net/wiki/POP_Series_3_(TCG)',
#  'POP Series 4': 'https://bulbapedia.bulbagarden.net/wiki/POP_Series_4_(TCG)',
#  'POP Series 5': 'https://bulbapedia.bulbagarden.net/wiki/POP_Series_5_(TCG)',
#  'POP Series 6': 'https://bulbapedia.bulbagarden.net/wiki/POP_Series_6_(TCG)',
#  'POP Series 7': 'https://bulbapedia.bulbagarden.net/wiki/POP_Series_7_(TCG)',
#  'POP Series 8': 'https://bulbapedia.bulbagarden.net/wiki/POP_Series_8_(TCG)',
#  'POP Series 9': 'https://bulbapedia.bulbagarden.net/wiki/POP_Series_9_(TCG)',
#  "McDonald's Collection 2011": 'https://bulbapedia.bulbagarden.net/wiki/McDonald%27s_Collection_2011_(TCG)',
#  "McDonald's Collection 2012": 'https://bulbapedia.bulbagarden.net/wiki/McDonald%27s_Collection_2012_(TCG)',
#  "McDonald's Collection 2013": 'https://bulbapedia.bulbagarden.net/wiki/McDonald%27s_Collection_2013_(TCG)',
#  "McDonald's Collection 2014": 'https://bulbapedia.bulbagarden.net/wiki/McDonald%27s_Collection_2014_(TCG)',
#  "McDonald's Collection 2015": 'https://bulbapedia.bulbagarden.net/wiki/McDonald%27s_Collection_2015_(TCG)',
#  "McDonald's Collection 2016": 'https://bulbapedia.bulbagarden.net/wiki/McDonald%27s_Collection_2016_(TCG)',
#  "McDonald's Collection 2017": 'https://bulbapedia.bulbagarden.net/wiki/McDonald%27s_Collection_2017_(TCG)',
#  "McDonald's Collection 2018": 'https://bulbapedia.bulbagarden.net/wiki/McDonald%27s_Collection_2018_(TCG)',
#  "McDonald's Collection 2019": 'https://bulbapedia.bulbagarden.net/wiki/McDonald%27s_Collection_2019_(TCG)',
#  'Winner cards': 'https://bulbapedia.bulbagarden.net/wiki/Winner_cards_(TCG)',
#  'Poké Card Creator Pack': 'https://bulbapedia.bulbagarden.net/wiki/Pok%C3%A9_Card_Creator_Pack_(TCG)',
#  'Pokémon Rumble': 'https://bulbapedia.bulbagarden.net/wiki/Pok%C3%A9mon_Rumble_(TCG)',
#  'Yellow A Alternate cards': 'https://bulbapedia.bulbagarden.net/wiki/Yellow_A_Alternate_cards_(TCG)',
#  'Prerelease cards': 'https://bulbapedia.bulbagarden.net/wiki/Prerelease_cards_(TCG)',
#  'Jumbo cards': 'https://bulbapedia.bulbagarden.net/wiki/Jumbo_cards_(TCG)',
#  'Miscellaneous Promotional cards 2009-2014': 'https://bulbapedia.bulbagarden.net/wiki/Miscellaneous_Promotional_cards_(TCG)/2009-2014',
#  'Miscellaneous Promotional cards 2015': 'https://bulbapedia.bulbagarden.net/wiki/Miscellaneous_Promotional_cards_(TCG)#2015',
#  'Miscellaneous Promotional cards 2016': 'https://bulbapedia.bulbagarden.net/wiki/Miscellaneous_Promotional_cards_(TCG)#2016',
#  'Miscellaneous Promotional cards 2017': 'https://bulbapedia.bulbagarden.net/wiki/Miscellaneous_Promotional_cards_(TCG)#2017',
#  'Miscellaneous Promotional cards 2018': 'https://bulbapedia.bulbagarden.net/wiki/Miscellaneous_Promotional_cards_(TCG)#2018',
#  'Miscellaneous Promotional cards 2019': 'https://bulbapedia.bulbagarden.net/wiki/Miscellaneous_Promotional_cards_(TCG)#2019',
#  'Error cards': 'https://bulbapedia.bulbagarden.net/wiki/Error_cards'}

# %%
print(sets["Cosmic Eclipse"])
# Out:
# https://bulbapedia.bulbagarden.net/wiki/Cosmic_Eclipse_(TCG)

# %% [markdown]
# Remove a couple of bad datasets

# %%
# for bad_set in [
#     "Legendary Collection",
#     "Base Set 2"
# ]:
#     try:
#         del sets[bad_set]
#     except:
#         pass

# %% [markdown]
# # Path functions

# %%
def get_set_path(set_name):
    return os.path.join(
        'data', 
        'pictures', 
        os.path.basename(set_name)
    )

def get_card_image_file_name(setname, image_link):
    return os.path.join(
        get_set_path(setname),
        os.path.basename(image_link)
    )

def make_dir_for_serie(set_name):
    """
    Creates a directory for storing card images   
    """
    os.makedirs(get_set_path(set_name), exist_ok=True)

# %% [markdown]
# # Pull in cards from series

# %%
def get_image_name(tag):
    image = tag.find('img')
    if image is None:
        res = tag.text
    else:
        res = image['alt']
    return res.strip()

# %%
def get_card_details(card_row, setname):
    """
    Extracts the details of a single card from a card row
    """
    tds = card_row.find_all('td')
    
    link_field = tds[2]
    
    res = {
        'id': tds[0].text.strip(),
        'rarity': get_image_name(tds[3])
    }
    
    
    if link_field is not None:
        res['name'] = link_field.text.strip()
        links = link_field.find_all('a')       
        link = next((l for l in links if "File:" not in l["href"]))
        if link is not None:
            res['link'] = base_url + link['href']
            res['card_file_name'] = get_card_image_file_name(setname, res['link'])
    
    res['type'] = get_image_name(card_row.find('th'))
    return(res)

# %%
def extract_card_details_for_set(set_name, set_link):
    """
    Generates all card links for a single series
    """
    card_soup = BeautifulSoup(requests.get(set_link).content)
    cards = pd.DataFrame()
    
    try:
        print(set_name)
        card_table = card_soup.find('table', class_ = 'multicol').find('table', width = '100%')
        card_rows = card_table.find_all('tr')[1:-1]

        make_dir_for_serie(set_name)
        cards = pd.DataFrame([get_card_details(cr, set_name) for cr in card_rows])
    finally:
        return cards

# %%
def extract_all_card_details(sets: dict):
    res = []
    for setname, link in sets.items():
        card_set = extract_card_details_for_set(setname, link)
        card_set["setname"] = setname
        res.append(card_set)
    return pd.concat(res, axis=0).reset_index(drop=True)

# %%
cards = extract_all_card_details(sets)
# Out:
# Base Set
# Jungle
# Fossil
# Base Set 2
# Team Rocket
# Gym Heroes
# Gym Challenge
# Neo Genesis
# Neo Discovery
# Neo Revelation
# Neo Destiny
# Legendary Collection
# Expedition Base Set
# Aquapolis
# Skyridge
# Southern Islands
# Sample Set
# Best of Game Cards
# Wizards Black Star Promos
# W Promotional cards
# Miscellaneous Promotional cards (TCG)/1999-2008
# Crosstrainer
# Unnamed Wizards Set
# Jamboree
# Legendary Collection 2
# EX Ruby & Sapphire
# EX Sandstorm
# EX Dragon
# EX Team Magma vs Team Aqua
# EX Hidden Legends
# EX FireRed & LeafGreen
# EX Team Rocket Returns
# EX Deoxys
# EX Emerald
# EX Unseen Forces
# EX Delta Species
# EX Legend Maker
# EX Holon Phantoms
# EX Crystal Guardians
# EX Dragon Frontiers
# EX Power Keepers
# Diamond & Pearl
# Mysterious Treasures
# Secret Wonders
# Great Encounters
# Majestic Dawn
# Legends Awakened
# Stormfront
# Platinum
# Rising Rivals
# Supreme Victors
# Arceus
# HeartGold & SoulSilver
# Unleashed
# Undaunted
# Triumphant
# Call of Legends
# Black & White
# Emerging Powers
# Noble Victories
# Next Destinies
# Dark Explorers
# Dragons Exalted
# Dragon Vault
# Boundaries Crossed
# Plasma Storm
# Plasma Freeze
# Plasma Blast
# Legendary Treasures
# Kalos Starter Set
# XY
# Flashfire
# Furious Fists
# Phantom Forces
# Primal Clash
# Double Crisis
# Roaring Skies
# Ancient Origins
# BREAKthrough
# BREAKpoint
# Generations
# Fates Collide
# Steam Siege
# Evolutions
# Sun & Moon
# Guardians Rising
# Burning Shadows
# Shining Legends
# Crimson Invasion
# Ultra Prism
# Forbidden Light
# Celestial Storm
# Dragon Majesty
# Lost Thunder
# Team Up
# Detective Pikachu
# Unbroken Bonds
# Unified Minds
# Hidden Fates
# Cosmic Eclipse
# 2004 World Championships
# 2005 World Championships
# 2006 World Championships
# 2007 World Championships
# 2008 World Championships
# 2009 World Championships
# 2010 World Championships
# 2011 World Championships
# 2012 World Championships
# 2013 World Championships
# 2014 World Championships
# 2015 World Championships
# 2016 World Championships
# 2017 World Championships
# 2018 World Championships
# EX Trainer Kit
# EX Trainer Kit 2
# Diamond & Pearl Trainer Kit
# HS Trainer Kit
# Black & White Trainer Kit
# XY Trainer Kit
# XY Trainer Kit: Bisharp & Wigglytuff
# XY Trainer Kit: Latias & Latios
# XY Trainer Kit: Pikachu Libre & Suicune
# Sun & Moon Trainer Kit: Lycanroc & Alolan Raichu
# Sun & Moon Trainer Kit: Alolan Sandslash & Alolan Ninetales
# Nintendo Black Star Promos
# DP Black Star Promos
# HGSS Black Star Promos
# BW Black Star Promos
# XY Black Star Promos
# SM Black Star Promos
# SWSH Black Star Promos
# POP Series 1
# POP Series 2
# POP Series 3
# POP Series 4
# POP Series 5
# POP Series 6
# POP Series 7
# POP Series 8
# POP Series 9
# McDonald's Collection 2011
# McDonald's Collection 2012
# McDonald's Collection 2013
# McDonald's Collection 2014
# McDonald's Collection 2015
# McDonald's Collection 2016
# McDonald's Collection 2017
# McDonald's Collection 2018
# McDonald's Collection 2019
# Winner cards
# Poké Card Creator Pack
# Pokémon Rumble
# Yellow A Alternate cards
# Prerelease cards
# Jumbo cards
# Miscellaneous Promotional cards 2009-2014
# Miscellaneous Promotional cards 2015
# Miscellaneous Promotional cards 2016
# Miscellaneous Promotional cards 2017
# Miscellaneous Promotional cards 2018
# Miscellaneous Promotional cards 2019
# Error cards
# /Users/jvandenhoven/miniconda3/envs/py3.7/lib/python3.7/site-packages/ipykernel_launcher.py:7: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   import sys

# %%
cards
# Out:
#                                          card_file_name     id  \
# 0          data/pictures/Base Set/Alakazam_(Base_Set_1)  1/102
# 1         data/pictures/Base Set/Blastoise_(Base_Set_2)  2/102
# 2           data/pictures/Base Set/Chansey_(Base_Set_3)  3/102
# 3         data/pictures/Base Set/Charizard_(Base_Set_4)  4/102
# 4          data/pictures/Base Set/Clefairy_(Base_Set_5)  5/102
# ...                                                 ...    ...
# 9937  data/pictures/Pokémon Rumble/Lucario_(Pok%C3%A...  12/16
# 9938  data/pictures/Pokémon Rumble/Skuntank_(Pok%C3%...  13/16
# 9939  data/pictures/Pokémon Rumble/Bastiodon_(Pok%C3...  14/16
# 9940  data/pictures/Pokémon Rumble/Rattata_(Pok%C3%A...  15/16
# 9941  data/pictures/Pokémon Rumble/Bibarel_(Pok%C3%A...  16/16
#
#                                                    link       name     rarity  \
# 0     https://bulbapedia.bulbagarden.net/wiki/Alakaz...   Alakazam  Rare Holo
# 1     https://bulbapedia.bulbagarden.net/wiki/Blasto...  Blastoise  Rare Holo
# 2     https://bulbapedia.bulbagarden.net/wiki/Chanse...    Chansey  Rare Holo
# 3     https://bulbapedia.bulbagarden.net/wiki/Chariz...  Charizard  Rare Holo
# 4     https://bulbapedia.bulbagarden.net/wiki/Clefai...   Clefairy  Rare Holo
# ...                                                 ...        ...        ...
# 9937  https://bulbapedia.bulbagarden.net/wiki/Lucari...    Lucario          —
# 9938  https://bulbapedia.bulbagarden.net/wiki/Skunta...   Skuntank          —
# 9939  https://bulbapedia.bulbagarden.net/wiki/Bastio...  Bastiodon          —
# 9940  https://bulbapedia.bulbagarden.net/wiki/Rattat...    Rattata          —
# 9941  https://bulbapedia.bulbagarden.net/wiki/Bibare...    Bibarel          —
#
#              setname       type
# 0           Base Set    Psychic
# 1           Base Set      Water
# 2           Base Set  Colorless
# 3           Base Set       Fire
# 4           Base Set  Colorless
# ...              ...        ...
# 9937  Pokémon Rumble   Fighting
# 9938  Pokémon Rumble   Darkness
# 9939  Pokémon Rumble      Metal
# 9940  Pokémon Rumble  Colorless
# 9941  Pokémon Rumble  Colorless
#
# [9942 rows x 7 columns]

# %% [markdown]
# # Data cleaning

# %%
def replace_value_in_column(df: pd.DataFrame, column: str, old_value, new_value):
    df[column][df[column] == old_value] = new_value

# %%
replace_value_in_column(cards, "type", "I", "T")
replace_value_in_column(cards, "type", "Su", "T [Su]")
replace_value_in_column(cards, "type", "St", "T [St]")

replace_value_in_column(cards, "rarity", "—", "Unknown rarity")
replace_value_in_column(cards, "rarity", "[[Image:Rarity_.png|]]", "Unknown rarity")

# %% [markdown]
# Store results

# %%
cards.to_csv("data/metadata.csv", index=False)

# %% [markdown]
# # Download images

# %% [markdown]
# ## A multithreaded function to retrieve multiple urls

# %%
def get_card_image_url(request_result):
    """
    Retrieves the page of a card and fetches the url of the card image
    """
    soup = BeautifulSoup(request_result.content)
    try:
        global tmp
        all_images = soup.find("div", id = 'mw-content-text').find('table').find_all('a', class_ = 'image')
        all_images = [img.find("img") for img in all_images]
        tmp = all_images
        for img in all_images:
            if int(img["width"]) > 50:
                return 'http:' + img['src']
    except:
        return None
    
def save_card_image(request_result, file_name):
    if request_result is not None:
        with open(file_name, "wb") as f:
            f.write(request_result.content)
        
def get_url_if_not_none(url):
    return None if url is None else requests.get(url)

# %%
def get_multiple_urls(urls, processes=8):
    with multiprocessing.Pool(processes=processes) as pool:
        pool_outputs = pool.map(get_url_if_not_none, urls)
    return pool_outputs

# %% [markdown]
# # This will take some time
#
# Download card pages

# %%
card_urls = cards["link"].tolist()
card_url_responses = get_multiple_urls(card_urls, processes=15)

# %% [markdown]
# Get card image links

# %%
card_image_links = [get_card_image_url(resp) for resp in card_url_responses]

# %% [markdown]
# Download card image pages

# %%
card_image_responses = get_multiple_urls(card_image_links, processes=15)

# %%
for response in card_image_responses:
    assert response is None or response.status_code == 200, "AAAAH"

# %%
for card_image_response, card_file_name in zip(card_image_responses, cards["card_file_name"]):
    save_card_image(card_image_response, card_file_name)
